# %% [markdown]
# <a href="https://colab.research.google.com/github/ratnaagustina08/DigitalClock/blob/main/Aktifitas2_citra.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import cv2

#baca gambar
img = cv2.imread('dft.tif', cv2.IMREAD_GRAYSCALE)

#brightness adjustment
brightness = 100
result = img.astype('int16') + brightness
result = result.clip(0, 255).astype('uint8')

#tampikan
plt.figure(figsize=(10, 10))
plt.subplot(1,2,1)
plt.title('Original')
plt.imshow(result, cmap='gray')
plt.axis('off')

plt.subplot(1,2,2)
plt.title('Brightness Adjustment')
plt.imshow(result, cmap='gray')
plt.axis('off')

plt.show()

# %%
breast = cv2.imread('breast.tif')

breast = cv2.cvtColor(breast, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(breast, cmap = 'gray')

# %%
breast_negative = 1 - breast

# %%
plt.imshow(breast_negative, cmap = 'gray')

# %%
plt.subplots(figsize=(10,10))

plt.subplot(1,2,2)
plt.imshow(breast, cmap='gray')

plt.subplot(1,2,2)
plt.imshow(breast_negative, cmap='gray')

# %%
moon = cv2.imread("moon.tif")
moon = cv2.cvtColor(moon, cv2.COLOR_BGR2RGB)

# %%
plt.subplots(figsize=(5,5))
plt.imshow(moon, cmap='gray')

# %%
thresh = 60

moon_th = moon > thresh

print(moon.shape)
# Out:
# (540, 466, 3)

# %%
import numpy as np
plt.imshow(moon_th.astype(np.uint8) * 255, cmap='gray')

#plt.imshow(moon_th, cmap='gray')
